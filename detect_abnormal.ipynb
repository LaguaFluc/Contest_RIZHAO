# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# path_data = 'data_file/data_train_corr_selected.csv'
path_data = 'data_file/train.csv'

# %%
data_train = pd.read_csv(path_data, header=0)
data_train.head()
# Out:
#    XINGBIE  AGE  HYZK  ZHIYE  ZHICHEN  ZHIWU
# 0        1   18    90     90      999      0
# 1        2   34    90     90      999      0
# 2        1   27    90     90      999      0
# 3        1   37    90     90      999      0
# 4        2   33    90     90      999      0

# %%
df_tmp = data_train.iloc[:, :5]
df_tmp.boxplot(return_type='dict')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26041970d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x260417ed220>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26041970880>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x260417edfa0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x260417ff100>,
# ...
#  'means': []}
